# %%
import pandas as pd

# %%
metadata = pd.read_csv('data/METADATA.csv')
metadata
# Out:
#     taxagroup           siteid  \
# 0       Water          E-A10HS
# 1       Water           E-A5HS
# 2       Water          E-B10HS
# 3       Water           E-B5HS
# 4       Water           E-B7HS
# ..        ...              ...
# 811      Fish             URUM
# 812      Fish   PV_GAL_ABRAINT
# 813      Fish   PV_GAL_LAMIAKO
# 814      Fish  PV_GAL_OLABEAGA
# 815      Fish   PV_GAL_RONTEGI
#
#                                               sitename country        seaname  \
# 0           Ondarroa (Embarcadero). High Tide. Surface      ES  Bay of Biscay
# 1            Ondarroa (Errenteria). High Tide. Surface      ES  Bay of Biscay
# 2                Plentzia (Puerto). High Tide. Surface      ES  Bay of Biscay
# 3               Plentzia (Abaniko). High Tide. Surface      ES  Bay of Biscay
# 4       Plentzia (Campo de fútbol). High Tide. Surface      ES  Bay of Biscay
# ..                                                 ...     ...            ...
# 811              Urumea (Arrastre zona media estuario)      ES  Bay of Biscay
# 812  Nerbioi exterior (Arrastre zona exterior masa ...      ES  Bay of Biscay
# 813  Nerbioi interior (Arrastre zona exterior masa ...      ES  Bay of Biscay
# 814  Nerbioi interior (Arrastre zona interior masa ...      ES  Bay of Biscay
# 815  Nerbioi interior (Arrastre zona media masa de ...      ES  Bay of Biscay
#
#      decimallatitude  decimallongitude  startyearcollected  endyearcollected  \
# 0          43.319883         -2.420973                1995              2023
# 1          43.322074         -2.443325                2002              2023
# 2          43.407626         -2.946287                1995              2023
# 3          43.396268         -2.924107                2002              2023
# 4          43.397900         -2.944209                2002              2023
# ..               ...               ...                 ...               ...
# 811        43.308616         -1.974026                2004              2022
# 812        43.341806         -3.025751                1989              2023
# 813        43.320628         -3.006055                1989              2023
# 814        43.267331         -2.957217                2002              2023
# 815        43.296997         -2.972804                1991              2023
#
#                                       samplingprotocol             name1  \
# 0    https://www.uragentzia.euskadi.eus/informacion...     Joana Larreta
# 1    https://www.uragentzia.euskadi.eus/informacion...     Joana Larreta
# 2    https://www.uragentzia.euskadi.eus/informacion...     Joana Larreta
# 3    https://www.uragentzia.euskadi.eus/informacion...     Joana Larreta
# 4    https://www.uragentzia.euskadi.eus/informacion...     Joana Larreta
# ..                                                 ...               ...
# 811  https://www.uragentzia.euskadi.eus/contenidos/...  Uriarte, Ainhize
# 812  https://www.uragentzia.euskadi.eus/contenidos/...  Uriarte, Ainhize
# 813  https://www.uragentzia.euskadi.eus/contenidos/...  Uriarte, Ainhize
# 814  https://www.uragentzia.euskadi.eus/contenidos/...  Uriarte, Ainhize
# 815  https://www.uragentzia.euskadi.eus/contenidos/...  Uriarte, Ainhize
#
#                  mail1          name2             mail2           name3  \
# 0     jlarreta@azti.es  Javier Franco  jafranco@azti.es  Izaskun Zorita
# 1     jlarreta@azti.es  Javier Franco  jafranco@azti.es  Izaskun Zorita
# 2     jlarreta@azti.es  Javier Franco  jafranco@azti.es  Izaskun Zorita
# 3     jlarreta@azti.es  Javier Franco  jafranco@azti.es  Izaskun Zorita
# 4     jlarreta@azti.es  Javier Franco  jafranco@azti.es  Izaskun Zorita
# ..                 ...            ...               ...             ...
# 811  aiuriarte@azti.es   Borja, Angel    aborja@azti.es             NaN
# 812  aiuriarte@azti.es   Borja, Angel    aborja@azti.es             NaN
# 813  aiuriarte@azti.es   Borja, Angel    aborja@azti.es             NaN
# 814  aiuriarte@azti.es   Borja, Angel    aborja@azti.es             NaN
# 815  aiuriarte@azti.es   Borja, Angel    aborja@azti.es             NaN
#
#                mail3
# 0    izorita@azti.es
# 1    izorita@azti.es
# 2    izorita@azti.es
# 3    izorita@azti.es
# 4    izorita@azti.es
# ..               ...
# 811              NaN
# 812              NaN
# 813              NaN
# 814              NaN
# 815              NaN
#
# [816 rows x 16 columns]

# %%
macroalgae = pd.read_csv('data/MACROALGAE.csv')
macroalgae

invertebrates = pd.read_csv('data/INVERTEBRATES.csv')
invertebrates
# Out:
#       datecollected  siteid         sampleid   basisofrecord  \
# 0        2010-01-20    E-A5    E-A5_20100120  MaterialSample
# 1        2013-01-30    E-A5    E-A5_20130130  MaterialSample
# 2        2016-01-26    E-A5    E-A5_20160126  MaterialSample
# 3        2019-01-21    E-A5    E-A5_20190121  MaterialSample
# 4        2021-03-15    E-A5    E-A5_20210315  MaterialSample
# ...             ...     ...              ...             ...
# 28036    2023-02-09  L-UR20  L-UR20_20230209  MaterialSample
# 28037    2023-02-09  L-UR20  L-UR20_20230209  MaterialSample
# 28038    2023-02-09  L-UR20  L-UR20_20230209  MaterialSample
# 28039    2023-02-09  L-UR20  L-UR20_20230209  MaterialSample
# 28040    2023-02-09  L-UR20  L-UR20_20230209  MaterialSample
#
#       minimumdepthinmeters maximumdepthinmeters                   taxaname  \
# 0               Intertidal           Intertidal   Potamopyrgus antipodarum
# 1               Intertidal           Intertidal                  Trematoda
# 2               Intertidal           Intertidal                   NEMERTEA
# 3               Intertidal           Intertidal                   NEMERTEA
# 4               Intertidal           Intertidal                   NEMERTEA
# ...                    ...                  ...                        ...
# 28036                    0                   48  Spiochaetopterus costarum
# 28037                    0                   48        Spiophanes convexus
# 28038                    0                   48        Spiophanes pulchram
# 28039                    0                   48      Tubulanus polymorphus
# 28040                    0                   48          Urothoe pulchella
#
#        taxanameid samplingeffort  parameter  parameter_value  \
# 0          147123    0.25 m2 * 3  Abundance             5.33
# 1           19948    0.25 m2 * 3  Abundance             1.33
# 2          152391    0.25 m2 * 3  Abundance             1.00
# 3          152391    0.25 m2 * 3  Abundance             3.00
# 4          152391    0.25 m2 * 3  Abundance             1.00
# ...           ...            ...        ...              ...
# 28036      129922     0.1 m2 * 3  Abundance            20.00
# 28037     1415952     0.1 m2 * 3  Abundance            20.00
# 28038     1415953     0.1 m2 * 3  Abundance            67.00
# 28039      122637     0.1 m2 * 3  Abundance             3.00
# 28040      103237     0.1 m2 * 3  Abundance            10.00
#
#       parameter_standardunit
# 0                     Ind/m2
# 1                     Ind/m2
# 2                     Ind/m2
# 3                     Ind/m2
# 4                     Ind/m2
# ...                      ...
# 28036                 Ind/m2
# 28037                 Ind/m2
# 28038                 Ind/m2
# 28039                 Ind/m2
# 28040                 Ind/m2
#
# [28041 rows x 12 columns]

# %%
biota = pd.read_csv('data/BIOTA.csv')
biota
#(12852, 12)

trainingset = biota.groupby('datecollected', group_keys=False).apply(lambda x: x.sample(frac=0.9))
trainingset.shape
validation_df = biota.drop(trainingset.index)  # Remaining 10%
validation_df.shape
#(1258, 12)
# Out:
# /tmp/ipykernel_7418/4292719444.py:5: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   trainingset = biota.groupby('datecollected', group_keys=False).apply(lambda x: x.sample(frac=0.9))
# (1258, 12)
